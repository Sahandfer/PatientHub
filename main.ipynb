# %%
from enum import Enum
from typing import Literal
from pydantic import BaseModel

class AgeGroup(str, Enum):
    CHILD = 'child'
    TEEN = 'teen'
    ADULT = 'adult'
    SENIOR = 'senior'

class Person(BaseModel):
    name: str
    age_group:

# %%
# Out:
# Person(name='Alice', age_group='<20')
